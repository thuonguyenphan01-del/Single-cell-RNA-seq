# %%
import json

# Đọc notebook
with open(r"C:\Users\ASUS\Desktop\python\Xử_lý_dữ_liệu_cơ_bản_với_file_GSM5226574_C51ctr_raw_counts_csv.ipynb", "r", encoding="utf-8") as f:
    nb = json.load(f)

# Nếu có metadata.widgets thì xoá
if "widgets" in nb.get("metadata", {}):
    del nb["metadata"]["widgets"]

# Ghi lại file sạch
with open(r"C:\Users\ASUS\Desktop\python\Xử_lý_dữ_liệu_cơ_bản_với_file_GSM5226574_C51ctr_raw_counts_csv.ipynb", "w", encoding="utf-8") as f:
    json.dump(nb, f, indent=2, ensure_ascii=False)

print("Notebook đã được làm sạch và lưu thành your_notebook_clean.ipynb")
# Out:
# Notebook đã được làm sạch và lưu thành your_notebook_clean.ipynb
